# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV, ElasticNetCV
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
df = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()

# %%
df.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   landcontour utilities  ... poolarea poolqc fence miscfeature miscval mosold  \
# 0         Lvl    AllPub  ...        0   None  None        None       0      2
# 1         Lvl    AllPub  ...        0   None  None        None       0      5
# 2         Lvl    AllPub  ...        0   None  None        None       0      9
# 3         Lvl    AllPub  ...        0   None  None        None       0      2
# 4         Lvl    AllPub  ...        0   None  None        None       0     12
#
#   yrsold  saletype  salecondition  saleprice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ### **_EDA  (Exporatory data analysis)_**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# id               1460 non-null int64
# mssubclass       1460 non-null int64
# mszoning         1460 non-null object
# lotfrontage      1201 non-null float64
# lotarea          1460 non-null int64
# street           1460 non-null object
# alley            91 non-null object
# lotshape         1460 non-null object
# landcontour      1460 non-null object
# utilities        1460 non-null object
# lotconfig        1460 non-null object
# landslope        1460 non-null object
# neighborhood     1460 non-null object
# condition1       1460 non-null object
# condition2       1460 non-null object
# bldgtype         1460 non-null object
# housestyle       1460 non-null object
# overallqual      1460 non-null int64
# overallcond      1460 non-null int64
# yearbuilt        1460 non-null int64
# yearremodadd     1460 non-null int64
# roofstyle        1460 non-null object
# roofmatl         1460 non-null object
# exterior1st      1460 non-null object
# exterior2nd      1460 non-null object
# masvnrtype       1452 non-null object
# masvnrarea       1452 non-null float64
# exterqual        1460 non-null object
# extercond        1460 non-null object
# foundation       1460 non-null object
# bsmtqual         1423 non-null object
# bsmtcond         1423 non-null object
# bsmtexposure     1422 non-null object
# bsmtfintype1     1423 non-null object
# bsmtfinsf1       1460 non-null int64
# bsmtfintype2     1422 non-null object
# bsmtfinsf2       1460 non-null int64
# bsmtunfsf        1460 non-null int64
# totalbsmtsf      1460 non-null int64
# heating          1460 non-null object
# heatingqc        1460 non-null object
# centralair       1460 non-null object
# electrical       1459 non-null object
# firstflrsf       1460 non-null int64
# secondflrsf      1460 non-null int64
# lowqualfinsf     1460 non-null int64
# grlivarea        1460 non-null int64
# bsmtfullbath     1460 non-null int64
# bsmthalfbath     1460 non-null int64
# fullbath         1460 non-null int64
# halfbath         1460 non-null int64
# bedroomabvgr     1460 non-null int64
# kitchenabvgr     1460 non-null int64
# kitchenqual      1460 non-null object
# totrmsabvgrd     1460 non-null int64
# functional       1460 non-null object
# fireplaces       1460 non-null int64
# fireplacequ      770 non-null object
# garagetype       1379 non-null object
# garageyrblt      1379 non-null float64
# garagefinish     1379 non-null object
# garagecars       1460 non-null int64
# garagearea       1460 non-null int64
# garagequal       1379 non-null object
# garagecond       1379 non-null object
# paveddrive       1460 non-null object
# wooddecksf       1460 non-null int64
# openporchsf      1460 non-null int64
# enclosedporch    1460 non-null int64
# threessnporch    1460 non-null int64
# screenporch      1460 non-null int64
# poolarea         1460 non-null int64
# poolqc           7 non-null object
# fence            281 non-null object
# miscfeature      54 non-null object
# miscval          1460 non-null int64
# mosold           1460 non-null int64
# yrsold           1460 non-null int64
# saletype         1460 non-null object
# salecondition    1460 non-null object
# saleprice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
print('Data shape before dropping columns with missing data : {}'.format(df.shape))

df.drop(['alley','miscfeature','fence','fireplacequ', 'poolqc'], axis = 1, inplace = True)

print('Data shape after dropping columns : {}'.format(df.shape))
# Out:
# Data shape before dropping columns with missing data : (1460, 81)
# Data shape after dropping columns : (1460, 76)

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = df.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)
plt.show()

# %%
'''Lets look at the correlated features'''
k = 15
corrmat = df.corr()
cols = corrmat.nlargest(k, 'saleprice')['saleprice'].index
cm = np.corrcoef(df[cols].values.T)
plt.subplots(figsize=(12,9))

sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# **_our target Sale price seems to be highly correlated with the feature in the heatmap above_**

# %% [markdown]
# **_Let's take a look at Null/NaN values in our data_**

# %%
missing_values = df.isnull().sum().sort_values(ascending=False)
percent_missing = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing = pd.concat([missing_values, percent_missing], axis = 1, keys = ['Total','percent'])[:20]
missing.head(8)
# Out:
#               Total   percent
# lotfrontage     259  0.177397
# garagefinish     81  0.055479
# garagetype       81  0.055479
# garagecond       81  0.055479
# garagequal       81  0.055479
# garageyrblt      81  0.055479
# bsmtexposure     38  0.026027
# bsmtfintype2     38  0.026027

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=missing.index, y=missing.percent)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
plt.show()

# %%
plt.hist(df['lotfrontage'])
plt.show()

# %%
#Group by neighborhood and fill in missing value by the median LotFrontage of all the neighborhood 
#due to skewed disrtribution
df['lotfrontage']= df.groupby('neighborhood')['lotfrontage'].transform(lambda x: x.fillna(x.median()))

# %%
for col in ('garagetype' , 'garagefinish', 'garagequal', 'garagecond'):
    df[col] = df[col].fillna('None')

# %%
df['garageyrblt'] = df['garageyrblt'].fillna('0')

# %%
for col in ('bsmtqual', 'bsmtcond', 'bsmtexposure', 'bsmtfintype1', 'bsmtfintype2'):
    df[col] = df[col].fillna('None')

# %%
df["masvnrtype"] = df["masvnrtype"].fillna("None")
df["masvnrarea"] = df["masvnrarea"].fillna(0)

# %%
# fill the missing value with the most common
df['electrical']=df['electrical'].fillna(df['electrical'].mode()[0])

# %%
#sanity check
df.isnull().sum().sort_values(ascending = False)
# Out:
# saleprice        0
# extercond        0
# roofstyle        0
# roofmatl         0
# exterior1st      0
# exterior2nd      0
# masvnrtype       0
# masvnrarea       0
# exterqual        0
# foundation       0
# salecondition    0
# bsmtqual         0
# bsmtcond         0
# bsmtexposure     0
# bsmtfintype1     0
# bsmtfinsf1       0
# bsmtfintype2     0
# bsmtfinsf2       0
# yearremodadd     0
# yearbuilt        0
# overallcond      0
# overallqual      0
# mssubclass       0
# mszoning         0
# lotfrontage      0
# lotarea          0
# street           0
# lotshape         0
# landcontour      0
# utilities        0
#                 ..
# wooddecksf       0
# openporchsf      0
# enclosedporch    0
# threessnporch    0
# screenporch      0
# poolarea         0
# miscval          0
# mosold           0
# yrsold           0
# saletype         0
# garagefinish     0
# garagetype       0
# heatingqc        0
# fireplaces       0
# centralair       0
# electrical       0
# firstflrsf       0
# secondflrsf      0
# lowqualfinsf     0
# grlivarea        0
# bsmtfullbath     0
# bsmthalfbath     0
# fullbath         0
# halfbath         0
# bedroomabvgr     0
# kitchenabvgr     0
# kitchenqual      0
# totrmsabvgrd     0
# functional       0
# id               0
# Length: 76, dtype: int64

# %% [markdown]
# ### _Dealing with outliers_

# %%
plt.scatter(df['grlivarea'],df['saleprice'])
plt.xlabel('grlivarea')
plt.ylabel('saleprice')
plt.show()

# %% [markdown]
# We have a couple of outliers that might cause our model to overfit. lets remove those points!

# %%
#deleting points
df = df.drop(df[df['id']== 1299].index)
df = df.drop(df[df['id']==524].index)

# %%
plt.scatter(df['grlivarea'],df['saleprice'])
plt.title('Scanity Check')
plt.xlabel('grlivarea')
plt.ylabel('saleprice')
plt.show()

# %%
plt.scatter(df['totalbsmtsf'],df['saleprice'])
plt.title('bsmt vs saleprice')
plt.show()

# %% [markdown]
# Instead of dropping those values I combined All the Square footage into total SF feature and it did solve the oulier problem I would have otherwise

# %%
# Adding total sqfootage feature 
df['totalsf'] = df['totalbsmtsf'] + df['firstflrsf'] + df['secondflrsf']

# %%
plt.scatter(df['totalsf'],df['saleprice'])
plt.title('Total SF vs saleprice')
plt.xlabel('grlivarea')
plt.ylabel('saleprice')
plt.show()

# %%
df['saleprice'].describe()
# Out:
# count      1458.000000
# mean     180932.919067
# std       79495.055285
# min       34900.000000
# 25%      129925.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: saleprice, dtype: float64

# %%
#scatterplot
sns.set()
cols = ['saleprice', 'overallqual', 'grlivarea', 'garagecars', 'totalsf', 'fullbath', 'yearbuilt']
sns.pairplot(df[cols], size = 2.5)
plt.show()

# %% [markdown]
# ## Normalizing the variables

# %%
from scipy import stats
from scipy.stats import norm, skew #for some statistics

#use the numpy fuction log1p which  applies log(1+x) to all elements of the column
df["saleprice"] = np.log1p(df["saleprice"])

#Check the new distribution 
sns.distplot(df['saleprice'] , fit=norm);
fig = plt.figure()
res = stats.probplot(df['saleprice'], plot=plt)
plt.show()

# %%
#use the numpy fuction log1p which  applies log(1+x) to all elements of the column
df["grlivarea"] = np.log1p(df["grlivarea"])

#Check the new distribution 
sns.distplot(df['grlivarea'] , fit=norm);
fig = plt.figure()
res = stats.probplot(df['grlivarea'], plot=plt)
plt.show()

# %%
#use the numpy fuction log1p which  applies log(1+x) to all elements of the column
df["totalsf"] = np.log1p(df["totalsf"])

#Check the new distribution 
sns.distplot(df['totalsf'] , fit=norm);
fig = plt.figure()
res = stats.probplot(df['totalsf'], plot=plt)
plt.show()

# %%
# converting the yrsold to a categorical variable
df['yrsold'] = df['yrsold'].astype(str)

# %%
df = pd.concat([df,pd.get_dummies(df.kitchenqual, prefix="kitchenqual")], axis=1)
df = pd.concat([df,pd.get_dummies(df.street, prefix="street")], axis=1)
df = pd.concat([df,pd.get_dummies(df.mszoning, prefix="mszoning",drop_first=True)],axis=1)
df = pd.concat([df,pd.get_dummies(df.yrsold, prefix='yrsold')], axis = 1)

dummy_column_names = list(pd.get_dummies(df.kitchenqual, prefix="kitchenqual").columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df.street, prefix="street").columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df.mszoning, prefix="mszoning",drop_first = True).columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df.yrsold, prefix='yrsold').columns)

# %%
X = df[['overallqual','totalsf','garagecars','grlivarea', 'lotfrontage']+dummy_column_names]
Y = np.log1p(df['saleprice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, 
                                                    test_size = 0.2, 
                                                    random_state = 465)

# %%
lrm = LinearRegression()

lrm.fit(X_train, y_train)

# We are making predictions here
y_preds_train = lrm.predict(X_train)
y_preds_test = lrm.predict(X_test)

print("R-squared of the model in training set is: {}".format(lrm.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lrm.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# R-squared of the model in training set is: 0.8687935836497598
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8375482827334924
# Mean absolute error of the prediction is: 0.008818262938077909
# Mean squared error of the prediction is: 0.0001438182411386843
# Root mean squared error of the prediction is: 0.011992424322824985
# Mean absolute percentage error of the prediction is: 0.3449383221855664

# %%
# Perform 6-fold cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lrm, X_train, y_train, cv=6)
print(scores.mean())
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# 0.8638150988449643
# Accuracy: 0.86 (+/- 0.02)

# %%
scores = cross_val_score(lrm, X_train, y_train, cv=10)
plt.plot(scores)
plt.show()
print(scores)
# Out:
# [0.81523101 0.89975202 0.87861261 0.88686439 0.87066584 0.84801536
#  0.8563659  0.83966536 0.86146444 0.87544097]

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(lrm, X_train, y_train, cv=5)
plt.scatter(y_train,y_pred)

# %%
from sklearn.linear_model import RidgeCV
ridge_cv = RidgeCV(cv =5)

ridge_cv.fit(X_train,y_train)
y_preds_train = lasso_cv.predict(X_train)
y_preds_test = lasso_cv.predict(X_test)

print("Best alpha value is: {}".format(ridge_cv.alpha_))
print("R-squared of the model in training set is: {}".format(ridge_cv.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(ridge_cv.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# Best alpha value is: 0.1
# R-squared of the model in training set is: 0.8687739906263618
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8371939416141365
# Mean absolute error of the prediction is: 0.009269399801099453
# Mean squared error of the prediction is: 0.0001631444617992468
# Root mean squared error of the prediction is: 0.012772801642523335
# Mean absolute percentage error of the prediction is: 0.36256250787679906

# %%
lasso_cv = LassoCV(cv=5)

lasso_cv.fit(X_train, y_train)

# We are making predictions here
y_preds_train = lasso_cv.predict(X_train)
y_preds_test = lasso_cv.predict(X_test)

print("Best alpha value is: {}".format(lasso_cv.alpha_))
print("R-squared of the model in training set is: {}".format(lasso_cv.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lasso_cv.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# Best alpha value is: 0.0002575957674537935
# R-squared of the model in training set is: 0.8532065253197109
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8129816561983728
# Mean absolute error of the prediction is: 0.009346928137785853
# Mean squared error of the prediction is: 0.00016556703566324824
# Root mean squared error of the prediction is: 0.012867285481532157
# Mean absolute percentage error of the prediction is: 0.3656136598666399

# %%
elasticnet_cv = ElasticNetCV(cv=5)

elasticnet_cv.fit(X_train, y_train)

# We are making predictions here
y_preds_train = elasticnet_cv.predict(X_train)
y_preds_test = elasticnet_cv.predict(X_test)

print("Best alpha value is: {}".format(elasticnet_cv.alpha_))
print("R-squared of the model in training set is: {}".format(elasticnet_cv.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(elasticnet_cv.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# Best alpha value is: 0.000515191534907587
# R-squared of the model in training set is: 0.8530936607376072
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8128756851450443
# Mean absolute error of the prediction is: 0.009351604877317808
# Mean squared error of the prediction is: 0.00016566085166444395
# Root mean squared error of the prediction is: 0.012870930489457394
# Mean absolute percentage error of the prediction is: 0.36579469709859824

# %% [markdown]
# lrm is the best fit model for this Dataset because it has higher r squared values as well as lower errors of the prediction. There is no overfitting in the model as shown by low diffence in the cv score.

# %% [markdown]
# ### _External datset_

# %%
rate = pd.read_csv(r'C:\\Users\Rahul Miglani\Untitled Folder\30_yr.csv')

# %%
rate.head()
# Out:
#      date  mortgage_30_yr
# 0  1971.0        7.541750
# 1  1972.0        7.383269
# 2  1973.0        8.044808
# 3  1974.0        9.187115
# 4  1975.0        9.047115

# %%
plt.plot(rate['date'], rate['mortgage_30_yr'])
plt.show()

# %%
rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
# date              49 non-null float64
# mortgage_30_yr    49 non-null float64
# dtypes: float64(2)
# memory usage: 880.0 bytes

# %%
df['date']= df['yrsold'].astype(int)

# %%
df_new = df['date']

# %%
df_1 = pd.merge(df_new, rate, on='date')

# %%
df_mort = pd.merge(df, df_1)

# %%
df_mort.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street lotshape landcontour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 2   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 3   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 4   1          60       RL         65.0     8450   Pave      Reg         Lvl
#
#   utilities lotconfig  ... mszoning_RH mszoning_RL mszoning_RM yrsold_2006  \
# 0    AllPub    Inside  ...           0           1           0           0
# 1    AllPub    Inside  ...           0           1           0           0
# 2    AllPub    Inside  ...           0           1           0           0
# 3    AllPub    Inside  ...           0           1           0           0
# 4    AllPub    Inside  ...           0           1           0           0
#
#   yrsold_2007 yrsold_2008  yrsold_2009  yrsold_2010  date  mortgage_30_yr
# 0           0           1            0            0  2008         6.02717
# 1           0           1            0            0  2008         6.02717
# 2           0           1            0            0  2008         6.02717
# 3           0           1            0            0  2008         6.02717
# 4           0           1            0            0  2008         6.02717
#
# [5 rows x 94 columns]

# %%
sns.barplot(x = df_mort['date'],y =  df_mort['mortgage_30_yr'])
plt.show()

# %%
df_mort.corr()['saleprice']
# Out:
# id               -0.022290
# mssubclass       -0.067557
# lotfrontage       0.373857
# lotarea           0.258071
# overallqual       0.822198
# overallcond      -0.035838
# yearbuilt         0.585951
# yearremodadd      0.567816
# masvnrarea        0.429549
# bsmtfinsf1        0.386145
# bsmtfinsf2        0.011232
# bsmtunfsf         0.224241
# totalbsmtsf       0.645476
# firstflrsf        0.619496
# secondflrsf       0.321867
# lowqualfinsf     -0.039052
# grlivarea         0.738148
# bsmtfullbath      0.239180
# bsmthalfbath     -0.004051
# fullbath          0.598749
# halfbath          0.313397
# bedroomabvgr      0.211196
# kitchenabvgr     -0.144662
# totrmsabvgrd      0.537680
# fireplaces        0.493072
# garagecars        0.681714
# garagearea        0.656856
# wooddecksf        0.339741
# openporchsf       0.324246
# enclosedporch    -0.149407
# threessnporch     0.052868
# screenporch       0.124051
# poolarea          0.076980
# miscval          -0.016681
# mosold            0.059012
# saleprice         1.000000
# totalsf           0.816756
# kitchenqual_Ex    0.416733
# kitchenqual_Fa   -0.209839
# kitchenqual_Gd    0.406511
# kitchenqual_TA   -0.541315
# street_Grvl      -0.043454
# street_Pave       0.043454
# mszoning_FV       0.121048
# mszoning_RH      -0.076040
# mszoning_RL       0.296985
# mszoning_RM      -0.347079
# yrsold_2006       0.012919
# yrsold_2007       0.035572
# yrsold_2008      -0.014109
# yrsold_2009      -0.024485
# yrsold_2010      -0.016546
# date             -0.035858
# mortgage_30_yr    0.036485
# Name: saleprice, dtype: float64

# %%
# converting the yrsold to a categorical variable
df_mort['yrsold'] = df_mort['yrsold'].astype(str)
df_mort['mortgage_30_yr'] = df_mort['mortgage_30_yr'].astype(str)

# %%
df_mort = pd.concat([df_mort,pd.get_dummies(df_mort.kitchenqual, prefix="kitchenqual")], axis=1)
df_mort = pd.concat([df_mort,pd.get_dummies(df_mort.street, prefix="street")], axis=1)
df_mort = pd.concat([df_mort,pd.get_dummies(df_mort.mszoning, prefix="mszoning",drop_first=True)],axis=1)
df_mort = pd.concat([df_mort,pd.get_dummies(df_mort.mortgage_30_yr, prefix='mortgage_30_yr')], axis = 1)
df_mort = pd.concat([df_mort,pd.get_dummies(df_mort.yrsold, prefix='yrsold')], axis = 1)

dummy_column_names = list(pd.get_dummies(df_mort.kitchenqual, prefix="kitchenqual").columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df_mort.street, prefix="street").columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df_mort.mszoning, prefix="mszoning",drop_first = True).columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df_mort.mortgage_30_yr, prefix = 'mortgage_30_yr').columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(df_mort.yrsold, prefix = 'yrsold').columns)

# %%
X = df_mort[['overallqual','totalsf','garagecars','grlivarea', 'lotfrontage']+dummy_column_names]
Y = np.log1p(df_mort['saleprice'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, 
                                                    test_size = 0.2, 
                                                    random_state = 465)

# %%
lrm = LinearRegression()

lrm.fit(X_train, y_train)

# We are making predictions here
y_preds_train = lrm.predict(X_train)
y_preds_test = lrm.predict(X_test)

print("R-squared of the model in training set is: {}".format(lrm.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lrm.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# R-squared of the model in training set is: 0.8629169512933739
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8617703824342149
# Mean absolute error of the prediction is: 0.00837585190164937
# Mean squared error of the prediction is: 0.00013053365266169967
# Root mean squared error of the prediction is: 0.011425132500837777
# Mean absolute percentage error of the prediction is: 0.32715566656537665

# %%
# Perform 6-fold cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lrm, X_train, y_train, cv=6)
print(scores.mean())
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# 0.862894625549058
# Accuracy: 0.86 (+/- 0.00)

# %%
scores = cross_val_score(lrm, X_train, y_train, cv=10)
plt.plot(scores)
plt.show()
print(scores)
# Out:
# [0.86058355 0.86367067 0.86112063 0.86378993 0.86359439 0.86047815
#  0.86426134 0.86380998 0.86410402 0.86349365]

# %%
# There is no over-fiiting in our model

# %%
from sklearn.model_selection import cross_val_predict
y_pred = cross_val_predict(lrm, X_train, y_train, cv=5)
plt.scatter(y_train,y_pred)

# %%
# Perform 6-fold cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(ridge_cv, X_train, y_train, cv=6)
print(scores.mean())
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

# %%
lasso_cv = LassoCV(cv=5)

lasso_cv.fit(X_train, y_train)

# We are making predictions here
y_preds_train = lasso_cv.predict(X_train)
y_preds_test = lasso_cv.predict(X_test)

print("Best alpha value is: {}".format(lasso_cv.alpha_))
print("R-squared of the model in training set is: {}".format(lasso_cv.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(lasso_cv.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# Best alpha value is: 0.0002444242480203853
# R-squared of the model in training set is: 0.8466763095744172
# -----Test set statistics-----
# R-squared of the model in test set is: 0.845818615820674
# Mean absolute error of the prediction is: 0.00873600809892986
# Mean squared error of the prediction is: 0.00014559730109783516
# Root mean squared error of the prediction is: 0.012066370668010955
# Mean absolute percentage error of the prediction is: 0.34124114996926275

# %%
# Perform 6-fold cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lasso_cv, X_train, y_train, cv=6)
print(scores.mean())
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# 0.8466580141374208
# Accuracy: 0.85 (+/- 0.00)

# %%
elasticnet_cv = ElasticNetCV(cv=5)

elasticnet_cv.fit(X_train, y_train)

# We are making predictions here
y_preds_train = elasticnet_cv.predict(X_train)
y_preds_test = elasticnet_cv.predict(X_test)

print("Best alpha value is: {}".format(elasticnet_cv.alpha_))
print("R-squared of the model in training set is: {}".format(elasticnet_cv.score(X_train, y_train)))
print("-----Test set statistics-----")
print("R-squared of the model in test set is: {}".format(elasticnet_cv.score(X_test, y_test)))
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds_test)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds_test)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds_test)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds_test) / y_test)) * 100))
# Out:
# Best alpha value is: 0.0004888484960407707
# R-squared of the model in training set is: 0.846632970807838
# -----Test set statistics-----
# R-squared of the model in test set is: 0.8457696096395404
# Mean absolute error of the prediction is: 0.00873791585537955
# Mean squared error of the prediction is: 0.0001456435788488629
# Root mean squared error of the prediction is: 0.012068288149065007
# Mean absolute percentage error of the prediction is: 0.3413140196615393

# %% [markdown]
# ### _Lrm and Ridge_cv are the best models because of their High R-squared and accuracy , The mortgage rates from the yr sold did improve the model r-squared from 0.8375 without to 0.8617 but the cv score stayed the same_
